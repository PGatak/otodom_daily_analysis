# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.pylab as pylab
import matplotlib
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
mpl.style.use('ggplot')
sns.set_style('white')
pylab.rcParams['figure.figsize'] = 9,5

# %% [markdown]
# Założenia:
# - ilość pokoi poniżej 5
# - ilość metrów poniżej 80
# - dzielnice: Czuby, Felin, Wrotków, Węglinek, Czechów
# - cena poniżej 850 tys.

# %%
df = pd.read_csv('data/results.csv', usecols=['meters', 'price', 'rooms', 'dealer', 'district'],
                 na_values=['Zapytajocenę', 'EMPTY'])

# %%
df.head(1)
# Out:
#    meters     price rooms          dealer  district
# 0   117.5  529000.0     7  Ofertaprywatna  Sławinek

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2492 entries, 0 to 2491
# Data columns (total 5 columns):
# meters      2492 non-null float64
# price       2489 non-null float64
# rooms       2492 non-null object
# dealer      2492 non-null object
# district    2492 non-null object
# dtypes: float64(2), object(3)
# memory usage: 97.5+ KB

# %%
df = df[df['district'].isin(['Czuby', 'Felin', 'Wrotków', 'Węglinek', 'Czechów'])]

# %%
df = df[df['meters'] < 80][df['price'] < 850000]

# %%
df.describe(include = 'all')
# Out:
#             meters          price rooms             dealer district
# count   982.000000     982.000000   982                982      982
# unique         NaN            NaN     6                 59        5
# top            NaN            NaN     3  ŻagielDomSp.zo.o.  Wrotków
# freq           NaN            NaN   479                109      356
# mean     53.398014  348364.292587   NaN                NaN      NaN
# std      12.870813   87719.830425   NaN                NaN      NaN
# min      26.920000  180440.000000   NaN                NaN      NaN
# 25%      45.150000  278160.000000   NaN                NaN      NaN
# 50%      53.100000  342114.000000   NaN                NaN      NaN
# 75%      62.580000  401400.000000   NaN                NaN      NaN
# max      79.390000  719500.000000   NaN                NaN      NaN

# %%
df.shape
# Out:
# (982, 5)

# %%
df.isnull().sum()
# Out:
# meters      0
# price       0
# rooms       0
# dealer      0
# district    0
# dtype: int64

# %% [markdown]
# ### PRICE M2

# %%
df["price_m2"] = round(df["price"] / df["meters"])
#df = df.drop('price', axis=1)

# %%
"najniższa cena", df.price_m2.min()
# Out:
# ('najniższa cena', 4286.0)

# %%
"najwyższa cena", df.price_m2.max()
# Out:
# ('najwyższa cena', 10265.0)

# %%
df['price_m2'].groupby([df['dealer'], df['district'], df['rooms']]).mean()
# Out:
# dealer                            district  rooms
# 3DLublinDevelopmentSp.zo.o.Sp.K.  Wrotków   1        6416.666667
#                                             2        6400.000000
#                                             3        6233.333333
#                                             4        6300.000000
# 3KLUCZEs.c.                       Felin     3        5866.666667
#                                                         ...
# ŻagielDomSp.zo.o.                 Czuby     2        7866.666667
#                                             3        7504.958333
#                                   Wrotków   2        6150.000000
#                                             3        6000.000000
#                                             4        6000.000000
# Name: price_m2, Length: 254, dtype: float64

# %%
facet = sns.FacetGrid(df, hue="rooms",aspect=4)
facet.map(sns.kdeplot,'price_m2',shade= True)
facet.set(xlim=(0, df['price_m2'].max()))
facet.add_legend()
plt.xlim(df.price_m2.min(), df.price_m2.max())
facet.savefig("diagrams/rooms_price_m2.png")

# %%
fig = plt.figure(1)
plt.title("Średnia cena za m2 w zależności od ilości pokoi")
plt.grid()
plt.ylabel("Cena za m2")
df["price_m2"].groupby(df["rooms"]).agg(np.mean).plot(color = (0.9,0.7,0.2))
plt.grid(True)
fig.savefig('diagrams/avg_price_m2_rooms.pdf')

# %% [markdown]
# ### DEALER

# %%
df.dealer.fillna("Ofertaprywatna", inplace=True)

# %% [markdown]
# ### Agenci nieruchomości z minimum 10 ofertami

# %%
df["dealer"].value_counts()[0:20]
# Out:
# 3KLUCZEs.c.                               205
# 4tepiętro                                 103
# FRANCZEWSKANieruchomościs.c.              100
# LUKsp.zo.o.SKA                             93
# LUKJacekWysokiński                         62
# ŻagielDomSp.zo.o.                          56
# Ofertaprywatna                             54
# Arena                                      48
# NieruchomościLalakPropertiesSpzo.o.SKA     46
# CLIVUSNieruchomości                        36
# HomeBrokerS.A.                             33
# HERMESHOUSE                                31
# BiuroNieruchomościKWADRAT                  28
# Lokum                                      23
# LubelskieMieszkania                        21
# Alfahouse                                  20
# BIGCITYBROKER                              18
# BESTHOUSENieruchomości                     17
# InvestorNieruchomościFranchise             16
# WMNieruchomości                            15
# Name: dealer, dtype: int64

# %%
top_dealers_list = df['dealer'].value_counts()[0:31].index.tolist()

# %% [markdown]
# ### Ilość ofert dla wszystkich agencji z podziałem na dzielnice, oraz ilość pokoi

# %%
df['district'].groupby([df['dealer'], df['district'], df['rooms']]).count()
# Out:
# dealer               district  rooms
# 3KLUCZEs.c.          Czuby     3.0       1
#                      Felin     2.0      20
#                                3.0      15
#                                4.0       6
#                      Węglinek  1.0      22
#                                         ..
# geoDOMNieruchomości  Felin     3.0       1
#                      Wrotków   4.0       1
# ŻagielDomSp.zo.o.    Wrotków   2.0      26
#                                3.0      22
#                                4.0       8
# Name: district, Length: 265, dtype: int64

# %%
df["dealer"].value_counts().hist(bins=30)

# %%
df['dealer_cat'] = 0

# %%
# for data in [df]:
#     data.loc[ df['dealer_cat'].value_counts().values <= 5, 'dealer_cat'] = 0,
#     data.loc[(df['dealer_cat'].value_counts().values > 5) & (df['dealer_cat'].value_counts().index <= 10), 'dealer_cat'] = 1,
#     data.loc[(df['dealer_cat'].value_counts().values > 10) & (df['dealer_cat'].value_counts().index <= 20), 'dealer_cat'] = 2,
#     data.loc[(df['dealer_cat'].value_counts().values > 20) & (df['dealer_cat'].value_counts().index <= 30), 'dealer_cat'] = 3,
#     data.loc[(df['dealer_cat'].value_counts().values > 30) & (df['dealer_cat'].value_counts().index <= 50), 'dealer_cat'] = 4,
#     data.loc[(df['dealer_cat'].value_counts().values > 50) & (df['dealer_cat'].value_counts().index <= 80), 'dealer_cat'] = 5,
#     data.loc[(df['dealer_cat'].value_counts().values > 80) & (df['dealer_cat'].value_counts().index <= 140), 'dealer_cat'] = 6,
#     data.loc[ df['dealer_cat'].value_counts().values > 140, 'dealer_cat'] = 7

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
district_cat = df['dealer']

# %%
district_cat_encoded, district_categories = district_cat.factorize()

# %%
dealer_cat1 = pd.DataFrame(district_cat_encoded)

# %%
df.dealer_cat = dealer_cat1

# %%
df = df.rename(columns={'0': 'dealer_cat'})

# %%
df.columns
# Out:
# Index(['meters', 'price', 'rooms', 'dealer', 'district', 'price_m2',
#        'dealer_cat'],
#       dtype='object')

# %%
df.dealer_cat.isnull().sum()
# Out:
# 692

# %% [markdown]
# ### ROOMS

# %%
df.rooms.value_counts()
# Out:
# 3.0    499
# 2.0    443
# 4.0    137
# 1.0    103
# Name: rooms, dtype: int64

# %%
facet = sns.FacetGrid(df, hue="rooms",aspect=4)
facet.map(sns.kdeplot,'meters',shade= True)
facet.set(xlim=(0, df['meters'].max()))
facet.add_legend()
plt.xlim(15, 80)
facet.savefig("diagrams/rooms_meters.png")

# %% [markdown]
# ### DISTRICT

# %%
df["district"].value_counts()
# Out:
# Wrotków     323
# Węglinek    290
# Czuby       278
# Felin       146
# Czechów     145
# Name: district, dtype: int64

# %%
df["district_cat"] = df["district"]

# %%
title_mapping = {"Wrotków": 0, "Węglinek": 1, "Czuby": 2, "Felin": 4, "Czechów": 5}
for data in [df]:
    data['district_cat'] = data['district_cat'].map(title_mapping)

# %%
facet = sns.FacetGrid(df, hue="district",aspect=4)
facet.map(sns.kdeplot,'meters',shade= True)
facet.set(xlim=(0, df['meters'].max()))
facet.add_legend()
plt.xlim(20, 85)
facet.savefig("diagrams/district_meters.png")

# %%
facet = sns.FacetGrid(df, hue="district",aspect=4)
facet.map(sns.kdeplot,'price_m2',shade= True)
facet.set(xlim=(0, df['price_m2'].max()))
facet.add_legend()
plt.xlim(4800, 6800)
facet.savefig("diagrams/district_price_m2.png")

# %%
df.plot(kind="scatter", x="meters", y="price_m2", alpha=1,
       c="district_cat", cmap=plt.get_cmap("plasma"), colorbar=True,  sharex=False)
from pandas.plotting import scatter_matrix

# %% [markdown]
# ### METERS

# %%
df["meters_cat"] = df["meters"]

# %%
df["meters_cat"].astype(int)
# Out:
# 1       59
# 2       53
# 6       63
# 7       40
# 9       67
#         ..
# 2791    66
# 2794    67
# 2796    56
# 2798    68
# 2800    73
# Name: meters_cat, Length: 1182, dtype: int64

# %%
df["meters_cat"].hist(bins=35)

# %%
for data in [df]:
    data.loc[ data['meters_cat'] <= 30, 'meters_cat'] = 0,
    data.loc[(data['meters_cat'] > 30) & (data['meters_cat'] <= 40), 'meters_cat'] = 1,
    data.loc[(data['meters_cat'] > 40) & (data['meters_cat'] <= 50), 'meters_cat'] = 2,
    data.loc[(data['meters_cat'] > 50) & (data['meters_cat'] <= 60), 'meters_cat'] = 3,
    data.loc[(data['meters_cat'] > 60) & (data['meters_cat'] <= 70), 'meters_cat'] = 4,
    data.loc[ data['meters_cat'] > 70, 'meters_cat'] = 5

# %%
df.meters_cat.value_counts()
# Out:
# 2.0    338
# 4.0    295
# 3.0    252
# 1.0    171
# 5.0    103
# 0.0     23
# Name: meters_cat, dtype: int64

# %%
df
# Out:
#       meters     price  rooms                                    dealer  \
# 1      59.48  344984.0    3.0                            Ofertaprywatna
# 2      53.41  320460.0    3.0                            Ofertaprywatna
# 6      63.00  399000.0    3.0                                 4tepiętro
# 7      40.17  259096.5    3.0              FRANCZEWSKANieruchomościs.c.
# 9      67.43  384351.0    3.0                               3KLUCZEs.c.
# ...      ...       ...    ...                                       ...
# 2791   66.80  285000.0    3.0  CapitalFinanseiNieruchomościKarolinaLato
# 2794   67.39  384190.0    3.0                    BESTHOUSENieruchomości
# 2796   56.00  349000.0    2.0                           WMNieruchomości
# 2798   68.50  389000.0    3.0                            HomeBrokerS.A.
# 2800   73.10  343000.0    4.0                                 WłasnyKąt
#
#       district  price_m2  dealer_cat  district_cat  meters_cat
# 1        Czuby    5800.0         0.0             2         3.0
# 2        Czuby    6000.0         1.0             2         3.0
# 6        Czuby    6333.0         3.0             2         4.0
# 7      Wrotków    6450.0         3.0             0         2.0
# 9     Węglinek    5700.0         3.0             1         4.0
# ...        ...       ...         ...           ...         ...
# 2791     Felin    4266.0         NaN             4         4.0
# 2794  Węglinek    5701.0         NaN             1         4.0
# 2796   Wrotków    6232.0         NaN             0         3.0
# 2798     Czuby    5679.0         NaN             2         4.0
# 2800     Czuby    4692.0         NaN             2         5.0
#
# [1182 rows x 9 columns]

# %% [markdown]
# ### PRZYGOTOWANIE DANYCH

# %%
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.linear_model import LogisticRegression 
from sklearn.preprocessing import PolynomialFeatures
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import KFold, GridSearchCV, cross_val_score, train_test_split

# %%
features_drop = ['meters', 'price', 'dealer', 'district']
df = df.drop(features_drop, axis=1)

# %%
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)
print("Uczące", len(train_set), ", testowe", len(test_set))
# Out:
# Uczące 945 , testowe 237

# %%
train = train_data.drop('price_m2', axis=1)
target = train_data['price_m2']

train_data.shape, target.shape
# Out:
# ((945, 5), (945,))

# %%
df.dealer_cat.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-602-59d13a2b949c> in <module>
# ----> 1 df.dealer_cat.info()
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'info'

# %% [markdown]
# ## KORELACJA

# %%
corr_df = df.corr()
corr_df["price_m2"].sort_values(ascending=False)
# Out:
# price_m2        1.000000
# dealer_cat     -0.033618
# district_cat   -0.108895
# rooms          -0.271713
# meters_cat     -0.322441
# Name: price_m2, dtype: float64

# %%
sns.set()
sns_plot = sns.pairplot(df, hue='rooms', size=2.5)
sns_plot.savefig("diagrams/correlation.png")
#sns.pairplot(df,diag_kind="kde")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-545-fb04f2c171dc> in <module>
#       1 sns.set()
#       2 sns_plot = sns.pairplot(df, hue='rooms', size=2.5)
# ----> 3 sns_plot.savefig("diagrams/correlation.png")
#       4 #sns.pairplot(df,diag_kind="kde")
#
# ~/.local/lib/python3.6/site-packages/seaborn/axisgrid.py in savefig(self, *args, **kwargs)
#      35         kwargs = kwargs.copy()
#      36         kwargs.setdefault("bbox_inches", "tight")
# ---> 37         self.fig.savefig(*args, **kwargs)
#      38
#      39     def add_legend(self, legend_data=None, title=None, label_order=None,
#
# ~/.local/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2059                     bbox_inches = self.figure.get_tightbbox(renderer,
# -> 2060                             bbox_extra_artists=bbox_artists)
#    2061                     pad = kwargs.pop("pad_inches", None)
#    2062                     if pad is None:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2375                 try:
#    2376                     bbox = ax.get_tightbbox(renderer,
# -> 2377                             bbox_extra_artists=bbox_extra_artists)
#    2378                 except TypeError:
#    2379                     bbox = ax.get_tightbbox(renderer)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4365         bb.append(axbbox)
#    4366
# -> 4367         self._update_title_position(renderer)
#    4368         if self.title.get_visible():
#    4369             bb.append(self.title.get_window_extent(renderer))
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    2547                     if (ax.xaxis.get_label_position() == 'top' or
#    2548                             ax.xaxis.get_ticks_position() in choices):
# -> 2549                         bb = ax.xaxis.get_tightbbox(renderer)
#    2550                     else:
#    2551                         bb = ax.get_window_extent(renderer)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1162         ticks_to_draw = self._update_ticks()
#    1163
# -> 1164         self._update_label_position(renderer)
#    1165
#    1166         # go back to just this axis's tick labels
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2019                 spine = self.axes.spines['bottom']
#    2020                 spinebbox = spine.get_transform().transform_path(
# -> 2021                     spine.get_path()).get_extents()
#    2022             except KeyError:
#    2023                 # use axes if spine doesn't exist
#
# ~/.local/lib/python3.6/site-packages/matplotlib/path.py in get_extents(self, transform)
#     504         control points appropriately.
#     505         """
# --> 506         from .transforms import Bbox
#     507         path = self
#     508         if transform is not None:
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:

# %%
train
# Out:
#       rooms  dealer_cat  district_cat  meters_cat
# 1539    3.0         NaN             5         4.0
# 2320    1.0         NaN             1         0.0
# 2791    3.0         NaN             4         4.0
# 2430    4.0         NaN             2         5.0
# 639     2.0         1.0             2         2.0
# ...     ...         ...           ...         ...
# 2472    2.0         NaN             1         2.0
# 2562    2.0         NaN             5         2.0
# 2677    3.0         NaN             1         2.0
# 2014    3.0         NaN             2         3.0
# 2647    2.0         NaN             2         2.0
#
# [945 rows x 4 columns]

# %% [markdown]
# # MODELOWANIE

# %%
feature_names = ["rooms", "dealer_cat", "district_cat", "meters_cat"]
features = train[feature_names].values
test_features = test[["rooms", "dealer_cat", "district_cat", "meters_cat"]].values

# %%
features
# Out:
# array([[ 3., nan,  5.,  4.],
#        [ 1., nan,  1.,  0.],
#        [ 3., nan,  4.,  4.],
#        ...,
#        [ 3., nan,  1.,  2.],
#        [ 3., nan,  2.,  3.],
#        [ 2., nan,  2.,  2.]])

# %%
decision_tree = DecisionTreeClassifier(random_state=1)
decision_tree = decision_tree.fit(features, target)
decision_tree.score(features, target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-548-7046304cc5b3> in <module>
#       1 decision_tree = DecisionTreeClassifier(random_state=1)
# ----> 2 decision_tree = decision_tree.fit(features, target)
#       3 decision_tree.score(features, target)
#
# ~/.local/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     814             sample_weight=sample_weight,
#     815             check_input=check_input,
# --> 816             X_idx_sorted=X_idx_sorted)
#     817         return self
#     818
#
# ~/.local/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     128         random_state = check_random_state(self.random_state)
#     129         if check_input:
# --> 130             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     131             y = check_array(y, ensure_2d=False, dtype=None)
#     132             if issparse(X):
#
# ~/.local/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     540         if force_all_finite:
#     541             _assert_all_finite(array,
# --> 542                                allow_nan=force_all_finite == 'allow-nan')
#     543
#     544     if ensure_min_samples > 0:
#
# ~/.local/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57     # for object dtype data, we only check for NaNs (GH-13254)
#      58     elif X.dtype == np.dtype('object') and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').
